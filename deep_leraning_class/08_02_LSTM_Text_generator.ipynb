# %%
import numpy as np
text = open('data/이광수_무정.txt', encoding='euc-kr').read()
print('말뭉치 크기:', len(text))
# Out:
# 말뭉치 크기: 323659

# %%
# 60개 글자로 된 시퀀스를 추출합니다.
maxlen = 60
# 세 글자씩 건너 뛰면서 새로운 시퀀스를 샘플링합니다.
step = 3
# 추출한 시퀀스를 담을 리스트
sentences = []
# 타깃(시퀀스 다음 글자)을 담을 리스트
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('시퀀스 개수:', len(sentences))

# 말뭉치에서 고유한 글자를 담은 리스트
chars = sorted(list(set(text)))
print('고유한 글자:', len(chars))
# chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리
char_indices = dict((char, chars.index(char)) for char in chars)

# 글자를 원-핫 인코딩하여 0과 1의 이진 배열로 바꿉니다.
print('벡터화...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 시퀀스 개수: 107867
# 고유한 글자: 1679
# 벡터화...

# %%
sentences[6]
# Out:
# '영어 교사 이형식은 오후 두시 사년급 영어 시간을 마치고 내려쪼이는 유월 볕에 땀을 흘리면서 안동 김장로의 '

# %%
next_chars[6]
# Out:
# '집'

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

# %%
from tensorflow.keras.optimizers import RMSprop
optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

random.seed(123)
start_index = random.randint(0, len(text) - maxlen - 1)

# 20 에포크 동안 모델을 훈련합니다
for epoch in range(1, 20):
    print('에포크', epoch)
    # 데이터에서 한 번만 반복해서 모델을 학습합니다
    model.fit(x, y, batch_size=128, epochs=1)

    # 시드 텍스트를 선택합니다
    seed_text = text[start_index: start_index + maxlen]
    print('--- 시드 텍스트: "' + seed_text + '"')

    # 여러가지 샘플링 온도를 시도합니다
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ 온도:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)

        # 시드 텍스트에서 시작해서 200개의 글자를 생성합니다
        for i in range(200):
            # 지금까지 생성된 글자를 원-핫 인코딩으로 바꿉니다
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            # 다음 글자를 샘플링합니다
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 에포크 1
# Train on 107867 samples
# 107867/107867 [==============================] - 36s 335us/sample - loss: 3.4100
# --- 시드 텍스트: "지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의"
# ------ 온도: 0.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 ‘이 있는 사람이가 아니하고 그 사람이가 있는 사람이가 있는 사람이가 있다. 그러고 그 사람이가 그 사람이 있는 사람이가 있다. 그러고 그 사람이 있는 사람이가 아니하고 그 사람이 있는 사람이라. 그러고 형식의 생각이 되었다. 그러고 그 어디 형식의 생각이 하고 그 사람이 있는 사람이가 있는 사람이라. 그러나 그 사람이가 그러나 그 사람이 있는 사람이라.
# ------ 온도: 0.5
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 모르는 무슨 듯이 하고 영채의 ‘영채는 이 있는 사람을 보고 영채의 정도 들어 사람이가 자기를 보고 얼굴이 아니하여 형식이가 우선은 형식을 하고 다만 그 사람이 있는 것이 보다. 그러고 영채의 말이 하고 부인에서 한 사람이 있다. 그러나 형식은 정한 힘이 있다. 그러나 형식의 ” 하고 남자는 태을 때에 형식의 사람이 있는 사람이가, 부인의 뜻을 하고 같다
# ------ 온도: 1.0
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 청문슴이 된 지금 좋은 습니다을 무슨 뜻을 듣고 파는 기쁘을  있다는 여자거나 교육에 일하온 터를 깨고 斷면 형식의 만다. 자기 있는 녁보랐다. 고개를 듣들인가, 았다. 그러므로 알다니’ 하고 안 책을 보고 무먹 영채의 경도 동안 번 “친었다. 이 ‘마음’ 한 오직셨와 가기람도 위하는 거러운 말을 하던 형식의 듯이 식사가 모른다.
# 형식이가 속을 피조참 그
# ------ 온도: 1.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 새생씨 편참하나 무슨 나움을 생각하는 왜욕“물떨리는 든 네트움와 그 뜻은데눈을 보고가 보이 할 때에누도 위하여 앞에 뒤고 므로 피는 둥느個같이 를 흔으게 점발구라! 짝방 도쳐이히 제사 흘리활인로세유또 만나 변다게 마아디인 마게려오려세 “내고의 구두버리가 없었으” 하며 그러려 거를 다” 하고 년래 을 모른다. 영채이운 죽은 제는 써 자기를 족어서 땡답을 온
# 에포크 2
# Train on 107867 samples
# 107867/107867 [==============================] - 34s 315us/sample - loss: 2.8972
# --- 시드 텍스트: "지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의"
# ------ 온도: 0.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 눈물이 들어진다. 그러나 형식은 영채의 집에 있는 것이 보고 그 사람이 있었다. 그러고 형식의 눈에는 그 사람이 없었다. 그러고 형식의 눈에는 형식의 집에 있는 것이 보고 자기의 일생이 있었다. 그러고 형식의 눈에는 형식의 집에 있는 것이 보고 그 사람이 있었다. 그러나 형식의 눈에는 형식의 눈에 있는 것이 보고 지금 지금 그 사람이 있었다. 그러나 형식
# ------ 온도: 0.5
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 무론 무슨 나무 이야기를 보고 그 집에 있는 일이 없었다. 그러나 형식의 얼굴은 형식의 가슴속에 보고 지금 지금 그 자기의 눈에 ‘그 사람을 보는 것이 되었다. 형식의 눈에는 형식의 정절을 지리고 얼굴의 일름이 보고 다 자기를 보았다. 형식은 형식의 눈에 있을 때에 형식의 손에 도 있는 것이라. 이 집이 없었다. 그러나 다 자기를 가면 노파를 보고 다 자
# ------ 온도: 1.0
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 모양을 그적한 소리칠이 차를 보어고 하기와, 영채의 연생을 두 흔시주아 하고 영채는 보기던하는 생각이 많을 채를 만난 인혼이요. 형식의 기계에는 불성히 제랑들이 큰 것이 구려라고는 하나는 혼자, 나는 자기의 생활을 모르고, 노파의 중에 다니 나를 잘못하면서 형식도 하였구나. 내가 있는 뒤에 채러 그러갔구니, 갔던 뒤 무슨 혼지 서 아니 렇게라.
# “장도 다
# ------ 온도: 1.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의거를 피가 전심을 숙좋다가 두 눈물이 . 조상이들의 물의반물
# 선할 세상없나 데신시 한상아과 정았을 수떠이 보기다. 래가 한참이나 눈을 은다물딸금가로 그래 선형이라도 가만히 식딸락에는 소리를 동날하억요. 보고 눈을 를 지으며,
# “그러께 허면서는 술이따례이고개’ 하고 자기를 때쁨다냐” 하고 변만이라이 동의가 집어매하여 려모인 것도 갈 워간가는 영감을 팔질 같
# 에포크 3
# Train on 107867 samples
# 107867/107867 [==============================] - 33s 306us/sample - loss: 2.7710
# --- 시드 텍스트: "지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의"
# ------ 온도: 0.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 사랑은 형식을 보았다. 그 사람은 그 사람을 생각하였다. 그 사람은 그 중에 하고 말았다. 그 사람은 형식을 보고 영채를 보았다. 그 사람은 형식을 보고 그 사람은 그 사람의 말을 하였다. 그 사람은 그 사람을 생각하였다. 그 사람은 형식을 보고 그 사람은 영채를 보았다. 그 사람은 그 사람을 보고 그 사람은 그 사람의 얼굴을 생각하였다. 그 사람은 형식
# ------ 온도: 0.5
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 사랑은 지금 자리에게 보았다. 그 사람은 어떤 선형과 여자가 ‘이 있으면 그 사람이 아니 있겠습니까” 하고 눈물을 흘리고 어디로 가지고 말하면서 생각하지 아니하는 것을 생각하였다. 그 사람은 자기의 눈물을 생각하였더니 하였다. 그 사람은 이 형식을 생각하고 영채를 보이는 것이다. 그 중에도 그 중에도 그 중에도 들어와 같은 남자는 있었다. 그 사람은 그
# ------ 온도: 1.0
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 별가 없음을 가치고 지아중에 놓고 모자 도때냐. 그면은 몸이 유이운 사람을 본 로 비가 죽어창 하려라도 한다. 그것이 그 ‘내가 산자가 돌아와서 목을 양에 만족던 경수도로나…….”
# “그래 이지 러다. 한 일이로 떠된 도어이 하면 이슨 말 잘못한 듯이 얼굴을 병국이나 왜 더러할 줄을 교육이. 안놓 보기도 머리 인동이른을 치고 ‘혹 일무이’ 약른 줄을 보았다
# ------ 온도: 1.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 머리에 달디께서 두어랍실 제 분명과 학러소리 있은 계입더 된 노파를 보았으면 찌가막한 위 내려지려  득화였이까, 분술껏 ” 병고 공리고 있을 피가 없의
# 봄을 떠닫으며 두길로 월화 뜻이나 하는 듯이,
#  자은 잘 동느점부친)한 각일많았강다가  소리를 생각하디거나 생각하지요” 하고 앞에서 중리었으나 김장없이라는 깨을의협기짝 남이다다하, 일어선다, 무슨 합관하듯
# 에포크 4
# Train on 107867 samples
# 107867/107867 [==============================] - 34s 312us/sample - loss: 2.6931
# --- 시드 텍스트: "지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의"
# ------ 온도: 0.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 눈물이  어린 것이 아니 있는 것이 아니하였다. 그 사람은 형식을 보고 그 사람의 얼굴을 보고 그 사람의 말을 하는 것이 아니요, 그 사람의 얼굴을 보고 형식의 말을 하는 것이 아니요, 그 사람은 형식의 눈을 보고 그 사람의 말을 하고 말을 한다. 그 사람은 형식의 눈을 보고 그 사람의 말을 하고 그 사람을 보고 형식의 눈을 보고 그 사람의 얼굴을 보고
# ------ 온도: 0.5
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 사람은 은 것을 보고 형식의 얼굴을 보았다. 그러나 형식은 영채를 보고 형식의 얼굴을 보고 눈을 보고  세상에 입을 하는 것이 아니요, ‘자기의 생명을 사랑하는 것이 있을까. 그러고 마일에 무슨 말이 있다. 형식의 집에는 자기의 마음을 생각하였다. 형식은 영채를 보고 노파는 ‘이 있다’ 하고 뿐이다. 그때에 그 두 사람은 자기를 하였다. 그러나 그런 형식
# ------ 온도: 1.0
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 아들에는 온도 혼에 남절을 때를 두어 ! 놈건을 터치고 왔거니 하시오, 아마다 빠히 모지를까. 그러면 근문하다 보교. 무심하오?”
# “내 는일너무” 하고 얼굴을 보며,
# “을 어떻게 님다” 하고 책을 온마와 병도 할 속에도 더 말을 그만 듣고 갔다. 양 할 생각이 유일치, 영채에게, 영채가 면서도 어습.”
# “그것은 주어한 지신에게 면 것 같이” 하고 서때 문
# ------ 온도: 1.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 저 ’과 주 생각한 말인가.께에 병국의 남편을 깊고, ‘설는 선형’, 죽아 들어야 할 줄만라고지.”
# “아가, 이 일저 들어나?” ‘다지 앉았면, 네싶구라’ 하였다. 배학식 는 무대 형식의 자?이 집의 지도록 병국이를 태모르고, 내가 ’ 놓하더라의는 김그는 모양으로 물 원문에만 대호 제벽온다.
# “다소니만니’ 하는데요, . 자기가 께서 요주하였으며 붙께서 라
# 에포크 5
# Train on 107867 samples
# 107867/107867 [==============================] - 33s 309us/sample - loss: 2.6177
# --- 시드 텍스트: "지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의"
# ------ 온도: 0.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 사람은 형식의 마음을 하고 그러나 그때에 그 사람의 말이 있는 것이 아니었다. 그러나 그 말이 있는 것이 아니었다. 그러나 그러나 그것을 생각하고, 그러나 그러나 그러나 그러나 그것을 보고 그러나 그것을 보고 그러나 그러나 그러나 그것을 보고 그러나 그것을 보고 그러나 그러나 그러나 그것을 보고 그러나 그러나 그것을 보고 그러나 그러나 그것을 보고 그러나
# ------ 온도: 0.5
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 생각이 나는 사람이 있었다. 영채는 형식의 얼굴을 보았다. 그러나 영채는 이 몸을 게 보고 이야기를 하였다. 그러나 그러나 그것을 만들고 서로 그러한 것을 보고 그러나 어떤 사람이 있는 것이 있었다. 그러나 그 으로 형식의 눈에는 이 기다리로 더욱 아무리 생각하고 형식에게는 영채의 말을 듣고 아무 사람이 없었다. 그러나 형식도 그 외미(상였을 보면 그러나
# ------ 온도: 1.0
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 과, 그 집에는 여학생하게 후에는 자식의 말이라, 을 거숙 같은 별물을 흘리지 아니하여, 마치는 손을 덕았다. 그러고 비실히 깨으로 허하고 고려로 형식과 교선로 구비로 많면서 놓인 적에 “‘중되었, 조선절을 후른다’ 하였다. 그러고 우선이가 자기일, 씨내에게 눈을 대기 만불한 것을 교하하였다. 사랑도 ) 이삼 일 지씩을 급 사람은 영채의 눈이 노인 자학요
# ------ 온도: 1.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 가만 아들 회상 있다. 다가 병욱이나 나게 하였다. ‘에’ 사오’ 저히 방을 께서 므로 노파이와, 누구의 주파 때에 차키” 하는 슬와 같이 자기의 여러 사람이 은. 둥또 김현수게 산작게다는 대로소식와 까자작어욱는지 하라니 돌려요면 악한의 입을 그린 말은는 세 동안 어떤 저사이더시미에 하여서로 면서와서는 마치 내 각처라락 형식절할 비힘을 노파의 전에는 (물
# 에포크 6
# Train on 107867 samples
# 107867/107867 [==============================] - 34s 314us/sample - loss: 2.5551
# --- 시드 텍스트: "지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의"
# ------ 온도: 0.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 말을 듣고 형식은 그 어린 생각하는 생각도 아니 하는 것을 보고 그 말을 듣고 그 사람의 말을 듣고 사람의 말을 듣고 부모를 보고 그 사람의 말을 듣고 말을 하는 듯하여 보고 그 사람의 말을 듣고 한 말을 하다 하는 말을 듣고 노파의 말을 듣고 형식은 형식을 보았다. 그러나 그 사람은 형식의 말을 듣고 가만히 형식을 보았다. 그러나 그 사람은 그 사람을
# ------ 온도: 0.5
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 말을 듣고 ‘아버님’ 하는 말을 하는 말을 하는 것을 보다 하는 생각도 없었다. 그러나 그는 영채의 말을 듣고 저 들어 눈물을 . 이 몸은 눈물을 흘리다가 형식의 말을 듣고 한다. 그러나 형식은 형식을 보았다. 그러나 그 사람의 말과 같다. 그래서,
# “그러면 어찌 하는 것을 보니 아니 들어 시오. 내 마는 부인이 되어 눈을  시작하고 영채 씨의 말을 이어
# ------ 온도: 1.0
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 기은를 함은 되라 하였다. 비학말들이 건마당 일고에간과의 사랑도 눈찌을 하는 것도 영채의 피명거을 리가온다. 하루 실에 병국이가 모자 이야기가 아니차마는 광기가 속만 전세한 싶답도 옷을 적내 못한 말워할 것을 보고 못 정하는 바람이 아버지 먼저까물이 그 구술미 만운 울을 내 지나는지 한다 하지도 아니하고 여전히 몸이 없어지고 . 풀지금 지금에 되는 생각이
# ------ 온도: 1.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 가는 해마으죽 원상의 은인으로 해서든 하어러라 형식은 없다. 것은 안 본하더라도 하나 나람다! 하기나 맛나는 듯하다 보면 이미 같은 새하지 못하는가도 려고은 감상과 모든 아직 날혔다. 영채는
# ‘ 를 자배’라 하였다. 영채의 었건일 형식은 건운다고 ! 화가 되고, 세상이 없이 거니와, 가만히 물어 지나 욱 몸을 너무 시파서 죄어내려고 남부예하로 ‘이줄 여네
# 에포크 7
# Train on 107867 samples
# 107867/107867 [==============================] - 34s 312us/sample - loss: 2.4948
# --- 시드 텍스트: "지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의"
# ------ 온도: 0.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 아들이 형식을 보고 형식은 그 사람을 보고 그 사람의 말을 듣는 것이다. 그러고 그 사람은 그 사람의 말을 듣는 것이 보인다. 그러고 그 사람은 그 사람의 말을 듣는 것이 되었다. 그러고 형식은 그 사람의 눈을 보고 그 사람의 말을 듣는 것이라. 그러고 형식은 그 사람의 말을 듣는 것이 보인다. 그러고 형식은 그 사람의 말을 듣는다. 그러고 형식은 그 사
# ------ 온도: 0.5
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 눈물을 ” 하고 기가 순애를 보았다. 그러고 형식은 선형의 사상을 대하여 가서 영채의 눈을  자기의 신세를 받아 ‘정이 있나요, 교육이라는 것이 있을까. 이러한 일이 아니 지금 어떤 사람에게 대하여 그러한 사람을 보기에 다 하고 얼마큼 형식에게 대하여서 형식은 아직 그 사람에게 대하여서는 이제는 하늘 저 들은 그 사람의 것을 깨트리고 형식을 보았다. 그러
# ------ 온도: 1.0
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 려무는 그래 기생으로 기장이라그려” 하고 하던 말과, 아내가 선형의 방손을  문을 조식은  들리밥과 는 까닭도 대문 모양을 보더니, 몸에 처음에 무엇인지 못하다고 영채의 마기가는 눈물로 형식의 잘 듯하여 허리를 가리가 되었다. 그 진정친에진 내가 그는 자기의 남랴의 탄 보지에 그친에‘만나지도 모르거니는 손으로 계향을 양희수의 종이가 으로 손린의 된 시당다
# ------ 온도: 1.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 돈서(와는 ‘물처에가 여사를 선형의 눈에로는 온 까닭이요, 마트 없는 것은 달보매 돈불라고 그 과연다 돌으면서 웃었다. ‘도부가 와 원려데 람이나 보인다” 면으앉고, 무엇 같은 기보을 그려한구고 찾아서 는 악친의 말도 선한 이뜻을 워서아이 랴. 이소말이 번식던 일밖에 청성를 안슨는지 할까죽 소리가 들었다. 그 인는 손른다자 여러 남자와 되었다. 소동 상디
# 에포크 8
# Train on 107867 samples
# 107867/107867 [==============================] - 33s 307us/sample - loss: 2.4431
# --- 시드 텍스트: "지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의"
# ------ 온도: 0.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 사랑을 보고 자기의 눈에 보이는 것을 보고 그 사람을 보고 그 사람을 보고 그 사람은 그 사람을 보고 그 사람을 보고 그 사람을 보고 그 사람을 보고 그 사람을 보고 형식은 그 집을 보고 그 사람을 보고 그 사람을 보고 그 사람을 보았다. 그러나 형식은 그 사람을 보이는 것같이 하였다. 그러나 형식은 형식을 보고 그 사람을 보고 ‘아이오’ 하였다. 그러나
# ------ 온도: 0.5
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 자기는 그러한 사람이라도 하는 모양으로, ‘조선 ’이라는 말을 듣고 그 집어지(학생)이라 하였다. 그러나 이 눈을 나서 분하여 마음을 들어 지나과 이러한 사람을 보았다. 그러나 자기는 생각하였다. 그러나 형식은 그 사람을 대하여 또 어떤 자기의 사랑이 있었다. 형식은 월향이라는 말을 듣고 말을 할 수 있을 것이라 하고 형식의 ‘내 사람’이라 하려 하는 사
# ------ 온도: 1.0
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 마음도 무루히 대학교를 내다보고 ‘동발 아이다가 가느?’ 하는 세상에 형식이란 자네의 영감을 동학감 하였는리요. 노파는 ‘미무슨 살시오 문의리기지요?”
# “나가 개옷을 내나다며 세상 사람 거의 우선만 같인가는 생각도 아니 개자이것들고 친란하르이야부네가 책을 달아 다였다. 또 형식은 수만 울이니, 무엇을 줄만 게는 것을 보는 모양으로 어랑스러아제 하는 양을
# ------ 온도: 1.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 한너도 이어 왔다. 소나이나 같내도 지가 방 오 김간에 만렬하는 줄을 위하였다. 영채는 분정과 신문제를 내지 비아쳐겠려도 병국고 머리(라통통하다가 열별금 몸을 아늘한 가만”는하고 ‘대긴
# 막구’ 한다. 형식은 것을 보고 이사이 줄게 보았다. 물편 세 정은 하며 일편 사람은 조기차 본 적적를 할 불 리 김녀성보까 단집으로 갔으려 하여도 )하기를 지금들의 ‘
# 에포크 9
# Train on 107867 samples
# 107867/107867 [==============================] - 33s 302us/sample - loss: 2.4007
# --- 시드 텍스트: "지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의"
# ------ 온도: 0.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 자기의 말을 듣고 형식이가 그 사람을 생각하였다. 그러고 그 사람은 형식의 눈에 들어 그 사람이 없었다. 그러고 그 사람은 형식을 보며,
# “그러면 그러고 그 이렇게 그 이렇게 그 이렇게 그 이렇게 그 사람을 보았다. 그 사람은 형식을 보고 그 이야기를 하고 그 사람을 보았다. 그러고 형식은 영채가 형식을 가르치고, 그 사람은 형식이가 이제 그 사람을 보았
# ------ 온도: 0.5
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 되는 영채는 얼른 모양이 저랑하여는 그 사람의 얼굴을 가지고 입술을 만다. 이러한 합실로 ‘번 다 다’ 하고 일생을 지어 모르되, 그 모양이 있을 것이라. 그러고 그 다만 사람은 그 자들의 모양을 보고 그 있을 사람이 있을 것이 아니요, 그러니까 하여 있는 영채의 마음은 그 월향에게 대하여 영채의 다리에 앉아서 형식이라는 말을 듣고 그 사람의 말을 하고
# ------ 온도: 1.0
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 형식이가 세상에 와 요간도 아니 없는 든 대로 돌아다니면서 형식이가 영채가 노파의 요 모란산을 주기를 이 눈을 보본 아들이 ? ‘’신이 월화와 지할 때마다 그 서양 사람들이 같이‘말. 이마 세수서 뒤
# 까일든생의 동거두 형 에 면서 무릎 위에서 들어하는 만원이 과어 자기 버상을 교육이라. 입마 여자가 었다. 형식은 그만 말하네 한 근래 와서 ‘아례오르 ’이
# ------ 온도: 1.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 형식가 무슨 생때으로 그직도 더번운 가음과 선형을 )과 두 삼물 가 아을 글이 병욱과 노래가 도일 살내, 저는 선형식가 날인사요이게만…… 영채 중도 들으갔던와의 바라평은 교학에 영러가서라데 하려라, 고소더서 원래 손에 영어박서라눈물을 말하면서 듣고 경년하이 그래 ‘실론 그가 영채’라 뿐일자요, 말할 생각이 짐에 더었겠어나리겠구나 하고 길가 하여므로 눈물을
# 에포크 10
# Train on 107867 samples
# 107867/107867 [==============================] - 33s 306us/sample - loss: 2.3576
# --- 시드 텍스트: "지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의"
# ------ 온도: 0.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 얼굴이 보인다. 그러나 형식은 형식의 얼굴을 보았다. 그러나 형식은 그 사람을 보았다. 그러나 그 사람은 형식의 얼굴을 보았다. 그러나 그 사람은 형식의 얼굴을 보았다. 그러나 그 사람은 형식의 얼굴을 보았다. 그러나 그 사람은 형식의 얼굴을 보았다. 그러나 그 사람은 형식의 얼굴을 보았다. 그러나 그 사람은 형식의 얼굴을 보았다. 그러나 그 사람은 형식
# ------ 온도: 0.5
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 대동강에 서양 사람은 아주 주는 것이라. 그러것과 생각도 없고, 영채가 어떤 얼굴을 보았다. 형식은 그 남자를 구원하여 보았다. 형식은 그 노파의 생각에 흔들고 자기가 없어서 그 처녀를 위하여 좋다는 생각과 상엇이 무슨 생각을 하여 본다. 그러나 그것이 영채를 하는 것을 보고 형식은 형식의 가슴을 다 가리에 ‘더욱 보았다. 오라 하면 한 사람이 없어요.
# ------ 온도: 1.0
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 가슴이 의찌기어 새로운 위함이를 , 서며분신 위에 왔다. 선형은 자기의 이일에 서러 노파, 웃으면서 그 들어가면 “어서 하는
# “감(는고)를 다 구원나이!” 하고 늘 말 안는. 우선은 열녀전, 좋은 사람이로구나. (었다. 건나는 오시지와, 내가 발적하구의 모든 단워으로 주어야 하여도 하는 든 대동강 , 아무것이다.하옥에는 결와 옥지를 그치고, 월향던 짐리
# ------ 온도: 1.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 모여펄한다. 이제는 아이지새이 . 사람건으로 재미가 있었다. 괴무은 ‘년손(이캄다나에 그린 사람이어!’
# 까행하기 몸이 그가 였다. 그러면 그만 차차 부알진사라가 물어 본다. 그 병인은 지금 오치고 딸수늘 도으로소 형식이라 하여느가 시작못 이 다는 개학교 당나이었어히이 ‘무녀내란가학든서 눈을 이 그, 더 겠다’ 하면서 머리를 보았다. 그러나 제 처껏 알애생
# 에포크 11
# Train on 107867 samples
# 107867/107867 [==============================] - 34s 311us/sample - loss: 2.3252
# --- 시드 텍스트: "지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의"
# ------ 온도: 0.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 사랑을 보고 그 사람의 말을 하였다. 그러고 영채는 이 말을 하였다. 그러나 그 사람은 형식의 얼굴을 보고 영채는 이 말을 생각하였다. 그러나 그 사람은 자기를 보고 이 말을 하였다. 그러나 그 사람은 자기의 부인을 하였다. 그러고 그 사람의 말을 하며, “여보게 하였으니…… 어디 가서 이 이 어나 오늘 같은 것이 아니라. 그러나 그것을 모르고 그 사람의
# ------ 온도: 0.5
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 부르는 하나 하였다. 그러나 그 사람의 집은 부친의 일생에 기생이 “이 나를 인생이란 말이요, 그 이 사람이 대동강에 이야기 하나 하여 자기의 마음이 자기가 이 게지. 그런데 나는 이 일을 좋아하여 ‘이렇게 생각하였다’ 하고 또 형식의 일생을 생각하였다. 그러고 ‘어찌 아니’ 하고 ‘이제 미 자기 생각하였다. 형식의 일생에 사랑은 모르던 것을 보니 없지마
# ------ 온도: 1.0
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 자리들은 어론한 사람과 얼마큼 고개를 들고 몸을 못 새 줄을 하고 영채를 보았는 것이 학생들을 있기의 누이의 기향의 눈물이 다 하여 오는 옷인 웃는 말은 양나같이 보시이. 그래 지금까지 생각과 가현가. 던져경인지도 모르게 신문을 면숙고 오라고 가지고 시선은 것을 생각하였다. 그러나 가만히 그 속에 후려보다는. 그러고는 종로한이 자기를 사랑하여 보고 눈을
# ------ 온도: 1.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 책은 기움을 부리고 형식의 하는 있는 가르라는 말에 다만 문득 장로로 과연 오시간에, 바녀향이 가면 차난 서장로 두 사람에게 질을 기직람이 면회나 듯한 것이 무슨 노파를 만함고 아, 두 종 “내의 이자없이오.”
# “그러면 이느니 나암는 이형식 씨에 가신니까 많은 전세 보였으니까요?” 하였다. 그러고도 ‘그네 다무심 좋지며구 청문서로 혹 다 죽었고’ 하고 그
# 에포크 12
# Train on 107867 samples
# 107867/107867 [==============================] - 33s 308us/sample - loss: 2.3001
# --- 시드 텍스트: "지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의"
# ------ 온도: 0.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 사랑과 같은 사람이 없었다. 그러나 형식은 영채가 이 말을 하고 그는 자기의 집에 보인고 하고 형식의 눈에 가는 것이 아니라 하고 형식의 눈에 본다. 그러나 그 사람은 형식의 얼굴을 보았다. 그러고 형식은 이 말을 하고 그 이상하다 하더라도 그러나 그 사람은 없고 그 사람이 없고 그 사람이 없고 그 사람과 같이 아니 보이는 것이라 하였다. 그러고 형식은
# ------ 온도: 0.5
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 사랑과 같이 다 하고 이야기를 생각하고 이 두 사람의 일이 되었다. 그러나 이 말을 하고 형식은 영채를 보고 영채의 얼굴을 보았다. 그러고 형식이가 자기를 그러하였다. 그러나 그 사람의 처녀가 아니 들었던 줄을 알고 자기의 일생에 부인이 나오는 말을 듣고 그 이상은 아직도 모르고 뒤에 한 눈이 다 돌리오다가 눈을 보고 그러고 형식의 눈에 더러운 소리가 되
# ------ 온도: 1.0
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 위에 되는 눈은 목사고 모여기서 보지 못시란 생각이 던 온통 사람에 제일 가슨 “저경하러?” 하고 이니 오끄 셨소던 방에 월화에게 만든 것이 그렇게 웃었다. 비하고 깨어(린 학생들도 오 벌 병국이 에  앉건마는 눈물 보. ‘것이 지할못이로구나’ 하였다. 형식이가 모처같이 마기도 그네에 무슨 제가 없던 이가 ‘심하한 사람으로 고개를 인데요?” 하고 벌써 노
# ------ 온도: 1.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의과 이 부덤의 어여이도 속으로 문떤가. 그파다가 없고 줄 자가가 보면 동경하여도 아주 학상라 하면 십선은 건경와 물지를 깨하늘 이제는 몸과 진정하여지라고 가 할 양반가. 예상리므로 를 월향과 들으면서도 (애도레하던 세를 면직에 못한 손가락을 심하던 마음이 놈을 내어지고 일찍 전유한 세상을 물만게 듯하고 치일정이 눈 인이나 없고 지나간 사랑오리가는 노는 결시
# 에포크 13
# Train on 107867 samples
# 107867/107867 [==============================] - 34s 315us/sample - loss: 2.2760
# --- 시드 텍스트: "지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의"
# ------ 온도: 0.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 말은 아니하였다. 그러나 그 사람은 그 사람을 대하여 아마 자기가 자기가 그러한 것을 생각하였다. 그러나 그 사람은 그 사람과 자기가 자기를 대하여 하였다. 그러나 그 뒤에는 그러한 사랑은 자기가 있었다. 그러나 그 사람은 그 사람과 형식을 보고 그러한 사람을 보고 그러한 사람을 보고 그러한 사람을 보고 그러한 사람을 보고 두 사람을 대하여 나는 것이 있
# ------ 온도: 0.5
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 사랑은 자기가 사랑하는 것이 아니라, 아까 하는 것이 아니요, 자기가 형식이가 이 그 사람과 같은 사람이 없음을 깨달았다. 그러고 형식은 아직 이 세상에 있는 듯이 팔을 잡으려는 듯하였다. 그러나 어떤 영채는 영채가 그 자리에 들어먹고, ‘아아, 오늘은 이 세상에 가는 것 같지’ 하였다. 마음에는 이래 일어나 하는 생각이 나서 일찍 사람에게 대하여 병국의
# ------ 온도: 1.0
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 말도 얼른 되지마는 물자, 그 집에서 서서 못 들고 지심으로 말을 대하여서 나무
# 일찍 정적 놓으로 전이장이 글데도 지지록 보인다. 형식은 것같이,
# “무론 이는 죽세병라 여러녀 전생의 데 모르지요.”
# 이 선형과 마음이 따생으로 달아온다.
# 이러한 뜻을 안다. 신날 울고 세상에 보인다. 그러나 자기가 노파의 일만 나을 수가 없고 그 종이를 혹은 어였다. 마음
# ------ 온도: 1.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의지도 있는 사람의 신술이나 자오가지은 만세의 잘하들가도는 적기도 있을 것을 온여 일리 있었었다. 유소름과 소른들이 무국게 김삼수에 있기 놀라기도 하는 말을 떠다가 위로에게 깨달은, 말을 경찰일생 일한 발스라는 도리어 때였다.
# 자 미식을 머리에니 심도 보겠다. 영채는 몸이 편지를 정지라리와  줄을 모르고다. 자기는 무만히 더한 찬미후 부찌 시다 영채는 더
# 에포크 14
# Train on 107867 samples
# 107867/107867 [==============================] - 33s 308us/sample - loss: 2.2499
# --- 시드 텍스트: "지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의"
# ------ 온도: 0.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 손으로 얼른얼른얼굴의 눈물을 놓인다. 그러나 그 사람의 모든 일이 있는 듯이 형식에게 대하여 이 말을 하는 듯이 형식의 눈을 보고 영채의 얼굴을 보며 영채의 얼굴을 보았다. 형식은 형식의 눈을 보고 그러고 일생이 아니라, 이제는 그 사람이 아니 되었는지는 모르는 사람이 아니요, 그러나 그것이 아니 그 사람의 말을 하는 듯이 한번 다 내어 보인다. 그래서
# ------ 온도: 0.5
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 사랑은 눈물을 흘리며 그 부인은 그러한 것을 생각하던 것을 생각하고, 이 말을 하던 자문도 있는 듯하다. 그러고 형식은 형식의 저 영채의 얼굴을 보았다. 그 까닭이라. 그래서 그 부인은 자기의 말을 이기로 같은 형식을 보고 자기의 생각에 영채가 아무리 생각하였다. 그러나 그 집에는 그 몸은 그 사람이 가지는 것이 아니요, 그러나 영채는 형식을 보고 그리는
# ------ 온도: 1.0
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 손은 뒤에서 가는 교사, 속 떠안 보는 일이 있고, 되앉은 무슨 말던 숙말도 없고 도리어 대리 죽은 사랑을 한다. 그는 아까 대대하면서 이희경을 어 돌리고 목사의 번는 비로소 이번에서 한써을다. 밖에 분하여도 도리가 남더러게 병욱을 유는히 (9음으로 우스워하고 말인다. 그를 아선한 영채를 나는다., 그가 듯하여 그는 그어들어올 때마다 그러나 울던 영채는
# ------ 온도: 1.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 전혼 못생적듯이 써여욱 던무 세상에 오려미안하고 호인하여 빛이 지어 모를 다른 세상이 이경늘에배서이 좀 흔계고 온 밤버진고 말없고 종동에 어느 거린내를 무슨그는 병욱은 을 다 함!” 하였다. 거야기를 비동하여 여자는 이정에만요’
# 사슨
# 세를 보는 일이?전에 없이 내 병이에게 안었던버니…… 한제는 …… 게들어었다.”
# “자시오!” 하고 우선은 려다고 생각하
# 에포크 15
# Train on 107867 samples
# 107867/107867 [==============================] - 33s 310us/sample - loss: 2.2250
# --- 시드 텍스트: "지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의"
# ------ 온도: 0.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 사랑은 아니 하는 것이 있으므로 그네가 그 사람의 말을 들었는가. 그러나 이 말을 한 사람에게 대하여 한다 하고 형식의 가슴속에 있었다. 형식은 이제야 그 사람의 말을 들었는가. 그러나 그 사람은 그 사람이로다. 그래서 그 사람이 형식을 보고 형식은 그 사람을 보고 한참이나 그 사람을 보고 형식의 가슴속에 대하여 한번 더 고개를 기울며 형식의 얼굴을 보고
# ------ 온도: 0.5
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 사랑이 되고 사람에게는 모양으로 형식의 얼굴을 보고 부인이 우선을 물어 보았다. 형식은 오늘 저녁 사람들을 모르고 일이 있었다. 그러나 그 사람은 그 아버님을 대하여서는 영채의 얼굴을 보고 무르던 생각이 난다. 그래서 어찌하여 형식이 다 얼굴이 ‘이 말을 그’ 하는 것이라. 그래서 어여 세상이 되었다. 그래서 안으면 조선 사람들은 한참 나오며,
# “여보게
# ------ 온도: 1.0
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 만전치를 내며,
# “선생만 에 배서 사회히 무어았을까. 영채는 형식의 형식이라고 , “그러면 제가 내가 내다오려요?” 영채는 공네를 주기
# 하니, 왜 누구시더러, 이 전고 ‘성문으로 제 ‘다’ 하는 말을 보고 앉았었다. 그러고 그 월향에게서 그가 요시에 자기도 다 십여 위이의 영채와 없었다. 자기가 죽은 사람을 가르치는 모양이교었다. 그러고 그 기생들의 모양
# ------ 온도: 1.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 만학교기를 불장서 이절!내에 쳐다흘었다. 우선은 일생에 그래할 감생각의(하기도 누기는 알 경상여“듣창려드로 없는가. 그런데 오래 ‘깨를 나를 좀 처음 형식 사람” 하면 웃었다. 자기는 형식은 가르는 차실에 얼굴 배늘 에도, 더 비음을 따르하니는다.
# “참 김녜, 세상에는 모기는 로구 말이말오야지” 하고 눈으로는 자기를 가지 주어서 자기의 향육일은 사람하면서
# 에포크 16
# Train on 107867 samples
# 107867/107867 [==============================] - 34s 311us/sample - loss: 2.2040
# --- 시드 텍스트: "지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의"
# ------ 온도: 0.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 말은 아니 들었어요” 하고 형식은 형식을 보며,
# “녜, 이 이러나 가지요. 그러고 그 사람의 말을 말하겠소. 그 사람의 말이는 모르는 것이 있어요” 하고 형식을 본다. 형식은 형식을 보고 웃는 고개를 숙이고 한 사람을 보았다. 형식은 형식을 보고 그 사람의 말을 하는 것이 아니요, 그 사람의 말은 아니 들었었다. 그러고 그 집에 가서 무슨 손으로 가만히
# ------ 온도: 0.5
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 눈을 볼 것이요. 이렇게 생각하였다. 그러고 형식은 한참이나 아니 다 하여 오라를 만든 사람이 되었다 하는 생각도 아니 한다. 그러나 이 말을 하려 하는 생각도 아니나 하였다. 우선은 형식의 눈에 내려오는 모양을 보고 그러한 사람의 모든 사람을 만나니 하였다. 그러고 노파는 기대에 형식의 등을 만나서 영채의 눈을 보았다. 형식은 그 이렇게 생각하고 형식을
# ------ 온도: 1.0
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 깨쁨이 조선의 위동분이 되었다.
# 어떤 그는 배학감에 생각하더니 기렸?고 저더니 그것이 속으로 갔었다. 형식의 실른 무인이 뜻장를 보았다. 형식은 다 생각하였다. 그 어면서는 다른 남양로 들었는지도 ‘뒤진런 사람은 기렸다는 것인 입동형할까 하고 지식간다. 둘이 오음 매개여어 더 슬술이 나 서서 자기네 눈을 보는다. 악욱이가 나는 듯이 할 생각이 나게 길을
# ------ 온도: 1.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 집이다 모랑이요. 어리가 갑자기 의기와 혼기와 친구나 다시 선형을 부름으로 말하네, 까려 들으려 나오히려왔노리 없해기는 생각을 던른 것이 형식 것같이 아니요, 소년은 무람이나 입고 저름아가니까 아명이 마론 일게 집으려기며, 혹 악동보이 처음 아렇게 미친 것이나 울지게 제 연대로 하여도 성산여 의으지나들으게 생각들을 도리면 가슴이 실려고도 많이 난는지 모르
# 에포크 17
# Train on 107867 samples
# 107867/107867 [==============================] - 33s 308us/sample - loss: 2.1879
# --- 시드 텍스트: "지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의"
# ------ 온도: 0.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 뜻을 보고 그리는 것이 아니라, 그러나 이 말을 하고 형식은 형식을 보고 형식은 그 사람을 보니 형식의 모양을 보고 자기의 생각이 나서 자기의 사랑을 생각하고, “그러면 어찌하고 그러한 사람이 있어요” 하고 형식의 모양이 말을 알면 하였다. 그러고 그 사람은 자기의 손을 잡아 놓고 웃는다. 형식은 영채의 얼굴을 보았다. 그러고 그 부인이 형식의 속에서 영
# ------ 온도: 0.5
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 뜻을 내어 돌아보고 그 소년을 하는 것이 아니었다. 그러나 무슨 무덤  인늘에 있는 사람이라 하는 말을 듣고, “아, 그렇지 아니 들어시오” 하고 ‘내가 사람이란 사람’이라고 기워하는 것을 보니, 그러나 영채는 이 이름을 내려는 것이라. 그러고 그 사람이 자기의 말을 알 수가 있다. 그러고 영채가 선형을 보니 소리를 내어 보았다. 형식은 한번 더 손을 잡
# ------ 온도: 1.0
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 말의 한 사람은 어느 사람을 움주여겨았는고……. 아아, 무슨 말이몸?” 하고 도로 (여相)을 비수는 이슨 빛을 아았는줄 그런 생각을 하고, 어게 희경이가에 잘한 ‘이삼인명’을 생각하려고는 것이 무실하여 이 아롱아요!”
# 하고 돌아오지마는, 형식은 그도 지금 영채 한 났다. 그러다가 놀라 어음날 소리가 !어 깨기하게. 서야 광한목을 서면서 비치소 사랑를 시지
# ------ 온도: 1.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 배명식은 영채를 비겠불랐도록 이 입술의 아가지는 교장은 학름을 집 주습다.
#
# 것이 다국 말하면 아마 학교가 하늘거로 가서 자중이가서 미국에 나온 줄을 하였다.
# “서로” 하고 우리가 두 사람의 열화를 보고 문직한 다른 어른다. 마까로 눈에는 거이겠지, 신양을 었으나 학교들을 여나는 잘라 하였다. 형식은 마치 생각하기 곁마에 온다리기도 하였다. 그론 자기도
# 에포크 18
# Train on 107867 samples
# 107867/107867 [==============================] - 33s 308us/sample - loss: 2.1677
# --- 시드 텍스트: "지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의"
# ------ 온도: 0.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 말을 듣고 형식은 그 사람을 보았다. 그러나 형식은 형식을 본다. 그 더구나 형식은 이러한 일을 생각하고 형식은 그 사람을 보았다. 그러나 그 사람은 그 사람의 말을 듣고 형식의 가슴속에 있던 말을 듣고 형식은 그 사람을 보았다. 그러나 그 사람은 형식의 생각에 형식은 그 사람의 말을 듣고 서로 어려운 것이나 일어나 그 사람이 되고 그 사람이 되고 그 아
# ------ 온도: 0.5
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 손을 내어 보며 형식의 모양을 바라고 웃으면서 형식의 얼굴을 보았다. 그 모든런는 얼굴을 보았다. 형식은 이 일어나서듯하고 전신에 오루에 (과 속에 들어 그 사람이 생각하고 눈을 감고 형식에게 대하여 어려운 듯이 남자로 자기의 말을 들었다. 그 사람은 형식의 가슴을 내려 보았다. 그러나 영채는 병욱이가 그 동안 속에서 자기의 사람을 받은 형식에게 있을 때
# ------ 온도: 1.0
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 유학이라 하는 몸이 더러운 여자의 말에 불쾌하다 그 마음이 차연, 웃는지도 나 일어나고 노파는 형식이라 하고, “이미 아니 보시는데…….”
# “양게지 아까) 어주의 앉았구나” 하였다. 그를 보며 웃었다.
# “학교은 주시오든다. 서양 그 속에 없어오?”
# “장에는 오른 안디로?”
# “아래, 과연 저가 다 나을 여겨어 별명은 안, 쾌한‘그든 다음까 씨 다 배학이겠소
# ------ 온도: 1.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 속에 조사적을 물어 알고―못하여,
# “키동은 무엇인데 물지 못” 하고 형식은 사경고양애는 올라와 서장이 음악한다. 저래! 그것들도 눈을  내던 모것을…… 이 속으로 말십한 없구나 하다.”
# “여보, 몰편 행주시된…… 얼학도 가셨어요. 힘이 없지마” 하고 신간 대로수 동고을 흔들다.
# “야 저 돌아요” 하고 저 우미러 칠팔 무론은 우치를 집으된 생각하고, 소위를
# 에포크 19
# Train on 107867 samples
# 107867/107867 [==============================] - 33s 309us/sample - loss: 2.1506
# --- 시드 텍스트: "지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의"
# ------ 온도: 0.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 뜻을 모르고, 이제 영채가 이 말을 하는 것이다. 그래서 형식은 영채를 보고 그 사람이 있는 사람이 없었다. 그러나 영채는 그 사람을 대하여 하는 것이 아니라, 그 사람은 자기가 무슨 무덤을 보고 그러한 사람이 없었다. 그러나 그 사람은 영채를 위하여 자기의 사랑을 보고 일어난다. 그래서 형식은 영채를 위하여 ‘이것이 사람’, 자기의 사랑이 아니라, 자기
# ------ 온도: 0.5
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 가는 그 부인이 얼마큼 무덤을 여기는 소리 형식의 생각이 있었다. 그러나 형식은 이 이 일러, 아니 들었다. 그러나 그네는 자기 정신을 모르고, “무론 그것이 다 알고 뜻이오.”
# “그러면 어찌 인사는 가지고 오셨어요. 그렇지 아니하고 그 어여쁘기도 하시오. 여기 들어가니” 하고 한 말 주기에 대하여 어느 기생들에게 대하여 한다. 그래서 형식의 말에는 이
# ------ 온도: 1.0
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 것은 내보기는 야른뜻같이 생기는 손님 아니 여기 된 집교사에 형식의 산이 유여도 울기기를 전장하였다. 거나 이러한 교내에 있던 소리가 두어 번 말한다. 그러나 아주 머리는 이삼 박거야 “(도 선배로 비심하여 주어지.”
# “와데다” 하고 이번 웃기도 불제불 가슴이 처음에는 며매우각하여 보던 이러한 모양으로,
# “이이가 기생이 된다. 그러나 듣고는 그것이 친절을
# ------ 온도: 1.2
# 지금껏 잊어버렸던 개가 입에 희끄무레한 무엇을 물고 따라온다. 영채는 반겨 그 개를 안았다. 그러나 그 개의 보지는 것이 이라 한 수 따는 것이 소년의 할 죽었소 표내라고는 그러할 줄을 알았던떤일을 편지마는 될는세 알까 새 조마으 소리아이야. 우리가 신문의 절이 지제가 된 다 비길에 본다. 형식은 또을 말고, 수학이 잘 알 것 같지도 모르지 하더니, 들에 본다.
#
# 주윽하기도 어떤 여자가 새, 말은 잘 잘 자다가 조선 침에 난 사람, 영채에게 세하려께도 들어우리라
