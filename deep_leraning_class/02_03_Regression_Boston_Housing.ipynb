# %%
import numpy as np
np.random.seed(123)

# %% [markdown]
# - 데이터 로딩

# %%
from keras.datasets import boston_housing

(x_train, y_train), (x_test, y_test) = boston_housing.load_data()
# Out:
# Using TensorFlow backend.

# %%
x_train[0]
# Out:
# array([  1.23247,   0.     ,   8.14   ,   0.     ,   0.538  ,   6.142  ,
#         91.7    ,   3.9769 ,   4.     , 307.     ,  21.     , 396.9    ,
#         18.72   ])

# %%
y_train[0]
# Out:
# 15.2

# %% [markdown]
# - 데이터 정규화

# %%
train_mean = x_train.mean(axis=0)
x_train -= train_mean
train_std = x_train.std(axis=0)
x_train /= train_std

x_test -= train_mean
x_test /= train_std
x_train[0]
# Out:
# array([-0.27224633, -0.48361547, -0.43576161, -0.25683275, -0.1652266 ,
#        -0.1764426 ,  0.81306188,  0.1166983 , -0.62624905, -0.59517003,
#         1.14850044,  0.44807713,  0.8252202 ])

# %% [markdown]
# - 모델 정의

# %%
from keras import models
from keras.layers import Dense

# %%
model = models.Sequential()
model.add(Dense(64, activation='relu', input_shape=(x_train.shape[1],)))
model.add(Dense(64, activation='relu'))
model.add(Dense(1))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 64)                896
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 5,121
# Trainable params: 5,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model, show_shapes=True)

# %% [markdown]
# - 컴파일을 포함한 모델 생성 함수 정의

# %%
def build_model():
    model = models.Sequential()
    model.add(Dense(64, activation='relu', input_shape=(x_train.shape[1],)))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
    return model

# %% [markdown]
# - K-Fold Cross Validation (k=4, epochs=100)

# %%
k = 4

# %%
num_val_sample = len(x_train) // k
num_epochs = 100
all_scores = []

# %%
for i in range(k):
    print('처리중인 폴드 : #', i+1)
    x_val = x_train[(i * num_val_sample) : ((i+1) * num_val_sample)]
    y_val = y_train[(i * num_val_sample) : ((i+1) * num_val_sample)]
    
    p_x_train = np.concatenate(
        [x_train[:(i * num_val_sample)],
         x_train[((i+1) * num_val_sample):]], axis=0)
    p_y_train = np.concatenate(
        [y_train[:(i * num_val_sample)],
         y_train[((i+1) * num_val_sample):]], axis=0)
    
    model = build_model()
    model.fit(p_x_train, p_y_train, epochs = num_epochs, batch_size=1, verbose=0)
    val_mse, val_mae = model.evaluate(x_val, y_val, verbose=0)
    all_scores.append(val_mae)
# Out:
# 처리중인 폴드 : # 1
# 처리중인 폴드 : # 2
# 처리중인 폴드 : # 3
# 처리중인 폴드 : # 4

# %%
all_scores
# Out:
# [2.24212908744812, 2.36230731010437, 2.8851897716522217, 2.47346830368042]

# %%
np.mean(all_scores)
# Out:
# 2.490773618221283

# %% [markdown]
# - K-Fold Cross Validation (k=4, epochs=500)

# %%
k=4
num_epochs = 500
all_scores = []

for i in range(k):
    print('처리중인 폴드 : #', i+1)
    x_val = x_train[(i * num_val_sample) : ((i+1) * num_val_sample)]
    y_val = y_train[(i * num_val_sample) : ((i+1) * num_val_sample)]
    
    p_x_train = np.concatenate(
        [x_train[:(i * num_val_sample)],
         x_train[((i+1) * num_val_sample):]], axis=0)
    p_y_train = np.concatenate(
        [y_train[:(i * num_val_sample)],
         y_train[((i+1) * num_val_sample):]], axis=0)
    
    model = build_model()
    history = model.fit(p_x_train, p_y_train,
                        validation_data=(x_val, y_val),
                        epochs = num_epochs, batch_size=1, verbose=0)
    mae_history = history.history['val_mae']
    all_scores.append(mae_history)
# Out:
# 처리중인 폴드 : # 1
# 처리중인 폴드 : # 2
# 처리중인 폴드 : # 3
# 처리중인 폴드 : # 4

# %%
mean_all_scores = [np.mean([x[i] for x in all_scores]) for i in range(num_epochs)]

# %% [markdown]
# - 결과 시각화

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(1, len(mean_all_scores)+1), mean_all_scores)
plt.xlabel('Epochs')
plt.ylabel('Validation MAE');

# %% [markdown]
# - Smoothing Curve를 사용한 시각화

# %%
def smooth_curve(points, factor=0.9):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            pre = smoothed_points[-1]
            smoothed_points.append(pre * factor + point * (1-factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# %%
smoothed_mae = smooth_curve(mean_all_scores[10:])

plt.plot(range(1, len(smoothed_mae)+1), smoothed_mae)
plt.xlabel('Epochs')
plt.ylabel('Validation MAE');

# %% [markdown]
# - 최종 모델

# %%
model = build_model()
model.fit(x_train, y_train, epochs=80, batch_size=16)
# Out:
# Epoch 1/80
# 404/404 [==============================] - 0s 129us/step - loss: 503.3920 - mae: 20.4839
# Epoch 2/80
# 404/404 [==============================] - 0s 34us/step - loss: 332.2097 - mae: 15.9534
# Epoch 3/80
# 404/404 [==============================] - 0s 34us/step - loss: 165.1317 - mae: 10.4116
# Epoch 4/80
# 404/404 [==============================] - 0s 34us/step - loss: 85.4606 - mae: 7.0764
# Epoch 5/80
# 404/404 [==============================] - 0s 32us/step - loss: 52.9563 - mae: 5.4446
# Epoch 6/80
# 404/404 [==============================] - 0s 32us/step - loss: 36.1202 - mae: 4.3551
# Epoch 7/80
# 404/404 [==============================] - 0s 31us/step - loss: 27.8649 - mae: 3.7344
# Epoch 8/80
# 404/404 [==============================] - 0s 32us/step - loss: 23.0151 - mae: 3.3855
# Epoch 9/80
# 404/404 [==============================] - 0s 31us/step - loss: 20.0467 - mae: 3.1337
# Epoch 10/80
# 404/404 [==============================] - 0s 32us/step - loss: 18.1447 - mae: 2.9039
# Epoch 11/80
# 404/404 [==============================] - 0s 31us/step - loss: 16.4269 - mae: 2.8176
# Epoch 12/80
# 404/404 [==============================] - 0s 33us/step - loss: 15.3324 - mae: 2.7155
# Epoch 13/80
# 404/404 [==============================] - 0s 32us/step - loss: 14.3165 - mae: 2.6050
# Epoch 14/80
# 404/404 [==============================] - 0s 31us/step - loss: 13.4943 - mae: 2.5654
# Epoch 15/80
# 404/404 [==============================] - 0s 31us/step - loss: 12.8033 - mae: 2.4636
# Epoch 16/80
# 404/404 [==============================] - 0s 31us/step - loss: 12.2993 - mae: 2.4580
# Epoch 17/80
# 404/404 [==============================] - 0s 32us/step - loss: 11.9077 - mae: 2.3883
# Epoch 18/80
# 404/404 [==============================] - 0s 30us/step - loss: 11.4826 - mae: 2.3680
# Epoch 19/80
# 404/404 [==============================] - 0s 31us/step - loss: 10.9894 - mae: 2.3373
# Epoch 20/80
# 404/404 [==============================] - 0s 32us/step - loss: 10.7173 - mae: 2.2974
# Epoch 21/80
# 404/404 [==============================] - 0s 33us/step - loss: 10.4288 - mae: 2.2981
# Epoch 22/80
# 404/404 [==============================] - 0s 34us/step - loss: 10.1811 - mae: 2.2746
# Epoch 23/80
# 404/404 [==============================] - 0s 32us/step - loss: 10.1074 - mae: 2.2432
# Epoch 24/80
# 404/404 [==============================] - 0s 31us/step - loss: 9.7520 - mae: 2.1713
# Epoch 25/80
# 404/404 [==============================] - 0s 30us/step - loss: 9.7870 - mae: 2.2448
# Epoch 26/80
# 404/404 [==============================] - 0s 30us/step - loss: 9.5680 - mae: 2.1440
# Epoch 27/80
# 404/404 [==============================] - 0s 30us/step - loss: 9.4411 - mae: 2.1552
# Epoch 28/80
# 404/404 [==============================] - 0s 30us/step - loss: 9.2678 - mae: 2.1225
# Epoch 29/80
# 404/404 [==============================] - 0s 32us/step - loss: 8.7384 - mae: 2.0855
# Epoch 30/80
# 404/404 [==============================] - 0s 31us/step - loss: 8.5115 - mae: 2.1083
# Epoch 31/80
# 404/404 [==============================] - 0s 31us/step - loss: 8.8948 - mae: 2.0617
# Epoch 32/80
# 404/404 [==============================] - 0s 34us/step - loss: 8.8846 - mae: 2.0833
# Epoch 33/80
# 404/404 [==============================] - 0s 31us/step - loss: 8.5851 - mae: 2.0453
# Epoch 34/80
# 404/404 [==============================] - 0s 31us/step - loss: 8.4932 - mae: 2.0635
# Epoch 35/80
# 404/404 [==============================] - 0s 31us/step - loss: 8.4080 - mae: 2.0185
# Epoch 36/80
# 404/404 [==============================] - 0s 32us/step - loss: 8.3041 - mae: 2.0388
# Epoch 37/80
# 404/404 [==============================] - 0s 32us/step - loss: 8.2694 - mae: 2.0110
# Epoch 38/80
# 404/404 [==============================] - 0s 31us/step - loss: 8.1189 - mae: 1.9796
# Epoch 39/80
# 404/404 [==============================] - 0s 30us/step - loss: 8.2754 - mae: 1.9870
# Epoch 40/80
# 404/404 [==============================] - 0s 31us/step - loss: 8.0065 - mae: 1.9858
# Epoch 41/80
# 404/404 [==============================] - 0s 32us/step - loss: 7.9103 - mae: 1.9673
# Epoch 42/80
# 404/404 [==============================] - 0s 32us/step - loss: 7.9032 - mae: 1.9616
# Epoch 43/80
# 404/404 [==============================] - 0s 31us/step - loss: 7.8310 - mae: 1.9329
# Epoch 44/80
# 404/404 [==============================] - 0s 32us/step - loss: 7.9129 - mae: 1.9701
# Epoch 45/80
# 404/404 [==============================] - 0s 34us/step - loss: 7.6765 - mae: 1.9388
# Epoch 46/80
# 404/404 [==============================] - 0s 32us/step - loss: 7.6663 - mae: 1.9239
# Epoch 47/80
# 404/404 [==============================] - 0s 32us/step - loss: 7.5974 - mae: 1.9066
# Epoch 48/80
# 404/404 [==============================] - 0s 33us/step - loss: 7.4802 - mae: 1.8669
# Epoch 49/80
# 404/404 [==============================] - 0s 30us/step - loss: 7.3965 - mae: 1.8897
# Epoch 50/80
# 404/404 [==============================] - 0s 31us/step - loss: 7.2795 - mae: 1.8879
# Epoch 51/80
# 404/404 [==============================] - 0s 32us/step - loss: 7.1773 - mae: 1.8581
# Epoch 52/80
# 404/404 [==============================] - 0s 31us/step - loss: 7.1759 - mae: 1.8483
# Epoch 53/80
# 404/404 [==============================] - 0s 32us/step - loss: 7.3183 - mae: 1.8847
# Epoch 54/80
# 404/404 [==============================] - 0s 32us/step - loss: 7.1607 - mae: 1.8646
# Epoch 55/80
# 404/404 [==============================] - 0s 29us/step - loss: 7.0375 - mae: 1.8547
# Epoch 56/80
# 404/404 [==============================] - 0s 30us/step - loss: 7.0218 - mae: 1.8714
# Epoch 57/80
# 404/404 [==============================] - 0s 30us/step - loss: 6.8444 - mae: 1.8078
# Epoch 58/80
# 404/404 [==============================] - 0s 32us/step - loss: 6.6756 - mae: 1.8155
# Epoch 59/80
# 404/404 [==============================] - 0s 31us/step - loss: 6.8001 - mae: 1.8286
# Epoch 60/80
# 404/404 [==============================] - 0s 34us/step - loss: 6.7541 - mae: 1.8378
# Epoch 61/80
# 404/404 [==============================] - 0s 29us/step - loss: 6.6821 - mae: 1.8330
# Epoch 62/80
# 404/404 [==============================] - 0s 31us/step - loss: 6.4423 - mae: 1.8314
# Epoch 63/80
# 404/404 [==============================] - 0s 33us/step - loss: 6.7717 - mae: 1.7960
# Epoch 64/80
# 404/404 [==============================] - 0s 31us/step - loss: 6.4819 - mae: 1.8065
# Epoch 65/80
# 404/404 [==============================] - 0s 32us/step - loss: 6.4480 - mae: 1.7739
# Epoch 66/80
# 404/404 [==============================] - 0s 33us/step - loss: 6.5154 - mae: 1.7842
# Epoch 67/80
# 404/404 [==============================] - 0s 33us/step - loss: 6.5218 - mae: 1.7583
# Epoch 68/80
# 404/404 [==============================] - 0s 33us/step - loss: 6.2958 - mae: 1.7413
# Epoch 69/80
# 404/404 [==============================] - 0s 34us/step - loss: 6.3186 - mae: 1.7557
# Epoch 70/80
# 404/404 [==============================] - 0s 32us/step - loss: 6.1144 - mae: 1.7043
# Epoch 71/80
# 404/404 [==============================] - 0s 33us/step - loss: 6.0057 - mae: 1.7241
# Epoch 72/80
# 404/404 [==============================] - 0s 32us/step - loss: 6.2619 - mae: 1.7721
# Epoch 73/80
# 404/404 [==============================] - 0s 33us/step - loss: 6.0858 - mae: 1.7022
# Epoch 74/80
# 404/404 [==============================] - 0s 33us/step - loss: 5.9907 - mae: 1.7447
# Epoch 75/80
# 404/404 [==============================] - 0s 34us/step - loss: 6.0409 - mae: 1.7167
# Epoch 76/80
# 404/404 [==============================] - 0s 33us/step - loss: 5.9758 - mae: 1.7105
# Epoch 77/80
# 404/404 [==============================] - 0s 36us/step - loss: 5.8394 - mae: 1.6919
# Epoch 78/80
# 404/404 [==============================] - 0s 34us/step - loss: 6.0275 - mae: 1.7388
# Epoch 79/80
# 404/404 [==============================] - 0s 33us/step - loss: 5.6659 - mae: 1.6702
# Epoch 80/80
# 404/404 [==============================] - 0s 34us/step - loss: 5.8526 - mae: 1.6810

# %%
results = model.evaluate(x_test, y_test)
results
# Out:
# 102/102 [==============================] - 0s 106us/step
# [19.33685960956648, 2.91691517829895]
