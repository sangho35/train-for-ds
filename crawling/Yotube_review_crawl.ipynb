# %% [markdown]
# # 1.StarCraft 2 AI  웹 크롤링

# %%
from selenium import webdriver as wd
from bs4 import BeautifulSoup
import time

# %%
browser = wd.Chrome(executable_path='chromedriver.exe')
url = 'https://www.youtube.com/watch?v=h7Q_57U4oj4'
browser.get(url)

last_page_height = browser.execute_script('return document.documentElement.scrollHeight')
while True:
    browser.execute_script('window.scrollTo(0,document.documentElement.scrollHeight)')
    time.sleep(3.0)
    new_page_height = browser.execute_script('return document.documentElement.scrollHeight')
    
    if new_page_height == last_page_height:
        break
    last_page_height = new_page_height

# %%
html_source = browser.page_source

# %%
soup = BeautifulSoup(html_source, 'html.parser')

# %%
youtube_likes = soup.select('span#vote-count-middle')
youtube_comments = soup.select('yt-formatted-string#content-text')

# %%
str_youtube_likes = []
str_youtube_comments =[]

for i in range(len(youtube_likes)):
    str_tmp = str(youtube_likes[i].text)
    str_tmp = str_tmp.replace('\n', '')
    str_tmp = str_tmp.replace('\t', '')
    str_tmp = str_tmp.replace('                ','')
    str_youtube_likes.append(str_tmp)
    
    str_tmp = str(youtube_comments[i].text)
    str_tmp = str_tmp.replace('\n','')
    str_tmp = str_tmp.replace('\t','')
    str_tmp = str_tmp.replace('                ','')
    str_tmp = str_tmp.lower()
    str_youtube_comments.append(str_tmp)
    
for i in range(len(str_youtube_likes)):
    print(str_youtube_likes[i], str_youtube_comments[i])
# Out:
#         693       this is my first ever video to reach 1 million views. thank you so much for watching. <3
#         1.4천       i could see auto-casting nukes as a recipe for hilarious disaster.random ghost in base: "zergling in my base? i think not! calling in a nuke!"
#         52       nukes are real scalelaunches nukeentire battlefield wiped out
#         217       the armored transport can use the units inside it to attack. it can be as powerful as a deathball full of infantry in a smaller size.
#         166       for april fool's, blizzard should make all the multiplayer matches with this mod, for april 1st.
#         1.2천       full auto...nukes...who decided those things should ever be combined?
#         412       don't battlecruisers drop command centres in the actual lore? it should be like a little city in the sky. way bigger than that at least. also, the nuke should cover the entire map.
#         393       you should play another round as zerg and use the overlord strat where you spawn so many overlords that your opponent can't see the screen, then drop all the units into their base.
#         26       "is that my nuke? are those my units? are those my vikings? oh yeah they are!"
#         153       lol "5 min of peace?" and proceeds to attack in 2
#         46       the pronunciation is magnificent. battlecruiser is now apparently bettercruiser. ;d
#         89       sci vessels should actually be larger than bcs based on canon. the one we see in the zerg cutscene in sc1 is enormous.
#         74       flashlights on marines are pretty cool, but they absolutely murder framerate. they should be removed.
#         695       all those nukes were you. you dropped hundreds of nukes on yourself.
#         10       so lets break this down, mind you i can’t maths so i am using a few reference pointslets start with our moon is about 1.7371 million meters long/widea typical us naval carrier is 333 meters long with a capacity of 6000 crew.the typical imperial i-class star destroyers are 1600-2100 meters long(that’s 133 to 175 feet) abit less than half as wide and around 1 / 4 as tall , it can carry a crew of 20-45 thousand. the tech is less bulky but the numbers are bit mehy, but then again they are troop and armored vehicle and fighter carriers too.most report the standard battle cruiser to be around 1000 meters long and about half as wide, crew wise i’d say its closer to what we got now. so they are a bit smaller than an og film star destroyer and 100ish meters shorter than the prequel venator class star destroyer’s.so you know a leviathan is 6700 meters long and about half as much wide/tall, so the volume it takes up is about 8 times that of a battle cruiser, and a mother ship is around half the size maybe 2.5 in volume of a leviathan, the ark ship is like 3-4 leviathan volume/space wise.the bastardized american football field is 109 meters longthe proper soccer football field is about the same 110 meters long.the city of new york is around 486022 meters long give or take, (302 sq mile, so its 302 miles from box edge to box edge). if if i am half or 30% off tis still 10-20 times bigger than these ships. so the common battle cruiser is not crazy big, only 4 or 5 times bigger in volume/space than the more common naval carriers, the larger battle cruisers are 2-3 times bigger than the common ones tho.
#         64       these assets would work well in the supreme commander engine.
#         118       "nukes are realistic scale." that's why it  covers maybe a few city blocks at most.
#         12       "5 minutes peace?"*3 minutes later*2 marine air drop he wont expect it
#         5       11:35, that was your auto-casted nuke lowko xdyou can see it's targeting the auto turret
#         2       how do you make the camera view go far away i cant do that, just close up and normal view but i cant make the camara go far away to have a huge view of all the map and better perspective of units can some one help me?
#         1       "nuke on autocast"---now there's something i hope to never experience in real life strategic planning
#         22       you  missed the merc compound. feelsbadman
#         658       the thor was originally built by scvs and not in factories
#         14       i’m actually kid of disappointed in how small the battlecruiser is. seemed a lot bigger in the trailer.
#         1       me : " marines you look like ants.marines : " wanna see how strong this ants bullets are.me : " sorry too disturb you good sirs.
#         2       wait what he didn't build a damn thor
#         1       "i feel like i'm in bw again"sold!
#         5       still waiting for the protos in real scale :(
#         30       the ship is like 1km, you can see it in a trailer
#         5       4:43 "one orbital gives you access to multiple mules?" what are you talking about. that's in the base game.
#         6       what i remember, in hots campain was a loading screen that shows hyperior and leviathan side to side. and the hyperior is so tiny next to it. leviathan could play with battlecruisers as with toy car.
#         1       ugh... why does he zoom in to look at the big entrances... zoom out so we can see how it enters the field
#         0       "say hello to my little friend!"is what you should have said as you sent in the battlecruiser
#         0       "5 minutes peace?" attacks 3:30 later. xd
#         10       i want to see a leviathan nuked xd
#         2       "research deez"----
#         0       hello everyone my name is lowko and welcome back to another race in real scale video. now what i''ve got for you today is terran in real scale
#         0       8:23 mute sound + video speed 0.25. admire explosion with the view.
#         0       keep it coming lowko :d. now to my favorite race: protoss.
#         3       12:06 "5 minutes peace?" that tilted me a bit given the fact you harassed your opponent with multiple nukes in succession decimating what little supply he had. it's like breaking someone's legs and then complaining if they break yours in turn.
#         0       16:42 aaahh what i was waiting for :d who called in the fleet?
#         0       the nuke from 17:22 was from your own bc ;) i love this real scale action!
#         76       "the size of that is insurrhurrhurr"-lowko 2016
#         0       that nukes o_o ..i cant stop laughing since i see baby marines :d :d:d:d:d:d:d
#         0       (in demoman's voices) tiny marines.
#         2       ha ha ha i  have never laughed this hard at a replay before... 10/10 would watch again. 7:50
#         0       27:19 i want every gun we have to fire on that man
#         0       this makes me want to play starcraft 2 once more
#         0       you gotta do more of this! loved it!
#         0       27:00 overkill literally
#         0       put on 0.5 speed and its hell. he sounds like he's melting.
#         1       i miss valkirys ,at least terran would have something amazing vs air
#         0       hah! love where your face is in the video, good call.
#         0       even the smallest nuke we have in real life today would glass that whole map
#         0       i love watching your channel! great job! :)
#         0       please tvz in real scale  <3  hahahaha
#         0       what pc you have?specs? cpu gpu mobo, psu,ram manufacturer :o hard drive/ssd? i'm curious

# %%
import pandas as pd
data = pd.DataFrame({'likes' : str_youtube_likes, 'reviews' : str_youtube_comments})
data
# Out:
#                  likes                                            reviews
# 0            693        this is my first ever video to reach 1 million...
# 1           1.4천        i could see auto-casting nukes as a recipe for...
# 2             52        nukes are real scalelaunches nukeentire battle...
# 3            217        the armored transport can use the units inside...
# 4            166        for april fool's, blizzard should make all the...
# ..                 ...                                                ...
# 95             0        hah! love where your face is in the video, goo...
# 96             0        even the smallest nuke we have in real life to...
# 97             0              i love watching your channel! great job! :)
# 98             0                   please tvz in real scale  <3  hahahaha
# 99             0        what pc you have?specs? cpu gpu mobo, psu,ram ...
#
# [100 rows x 2 columns]

# %%
data['likes']=data['likes'].str.replace('천', 'e3').astype('float32')
data
# Out:
#      likes                                            reviews
# 0    693.0  this is my first ever video to reach 1 million...
# 1   1400.0  i could see auto-casting nukes as a recipe for...
# 2     52.0  nukes are real scalelaunches nukeentire battle...
# 3    217.0  the armored transport can use the units inside...
# 4    166.0  for april fool's, blizzard should make all the...
# ..     ...                                                ...
# 95     0.0  hah! love where your face is in the video, goo...
# 96     0.0  even the smallest nuke we have in real life to...
# 97     0.0        i love watching your channel! great job! :)
# 98     0.0             please tvz in real scale  <3  hahahaha
# 99     0.0  what pc you have?specs? cpu gpu mobo, psu,ram ...
#
# [100 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(max_features = 5000, stop_words='english')

# %%
tdm = cv.fit_transform(data['reviews'])

# %%
tdm.shape
# Out:
# (100, 563)

# %%
word_count = pd.DataFrame({
    '단어' : cv.get_feature_names(),
    '빈도' : tdm.sum(axis=0).flat
})

# %%
word_count.head()
# Out:
#        단어  빈도
# 0      00   2
# 1      06   1
# 2      10   3
# 3    1000   1
# 4  100ish   1

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(background_color='white', max_words=5000, width=400, height=300)

# %%
count_dic = word_count.set_index('단어')['빈도'].to_dict()

# %%
cloud = wc.fit_words(count_dic)

# %%
cloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x27A150FAFC8>
